# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + 'washington'
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -120.5015, 'lat': 47.5001},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 36.52,
#   'feels_like': 32.05,
#   'temp_min': 31.95,
#   'temp_max': 41.4,
#   'pressure': 1020,
#   'humidity': 70,
#   'sea_level': 1020,
#   'grnd_level': 960},
#  'visibility': 10000,
#  'wind': {'speed': 5.41, 'deg': 280, 'gust': 4.99},
#  'clouds': {'all': 87},
#  'dt': 1676685223,
#  'sys': {'type': 2,
#   'id': 2003593,
#   'country': 'US',
#   'sunrise': 1676646272,
#   'sunset': 1676683668},
#  'timezone': -28800,
#  'id': 5815135,
#  'name': 'Washington',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(0)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdesc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weatherdesc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | podgornoye
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | mpanda
# Processing Record 4 of Set 1 | nishihara
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | stoyba
# City not found. Skipping...
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | novikovo
# Processing Record 11 of Set 1 | alcantara
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | billings
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | saint anthony
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | macapa
# Processing Record 19 of Set 1 | yumen
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | akureyri
# Processing Record 22 of Set 1 | manado
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 1 | kindu
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | presidente epitacio
# Processing Record 31 of Set 1 | lithakia
# Processing Record 32 of Set 1 | ponta delgada
# Processing Record 33 of Set 1 | saskylakh
# Processing Record 34 of Set 1 | novoagansk
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | gunnedah
# Processing Record 37 of Set 1 | katherine
# Processing Record 38 of Set 1 | kodinsk
# Processing Record 39 of Set 1 | mumford
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 1 | jalu
# Processing Record 44 of Set 1 | pringsewu
# Processing Record 45 of Set 1 | westport
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | poum
# Processing Record 50 of Set 1 | dingli
# Processing Record 1 of Set 2 | carbonear
# Processing Record 2 of Set 2 | husavik
# Processing Record 3 of Set 2 | olinda
# Processing Record 4 of Set 2 | grindavik
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | jundiai
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | cockburn town
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | nyandoma
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | muros
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | hasaki
# Processing Record 19 of Set 2 | maceio
# Processing Record 20 of Set 2 | lagoa
# Processing Record 21 of Set 2 | qunduz
# Processing Record 22 of Set 2 | omboue
# Processing Record 23 of Set 2 | tsabong
# Processing Record 24 of Set 2 | mirador
# Processing Record 25 of Set 2 | acarau
# Processing Record 26 of Set 2 | itarema
# Processing Record 27 of Set 2 | ugep
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | hoquiam
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | turukhansk
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | nerja
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | avera
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | kashi
# Processing Record 41 of Set 2 | shingu
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | abha
# Processing Record 44 of Set 2 | masuda
# Processing Record 45 of Set 2 | orzhytsya
# Processing Record 46 of Set 2 | tilichiki
# Processing Record 47 of Set 2 | kiunga
# Processing Record 48 of Set 2 | aklavik
# Processing Record 49 of Set 2 | atar
# Processing Record 50 of Set 2 | carnot
# Processing Record 1 of Set 3 | bathsheba
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | faanui
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | lavrentiya
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | guerrero negro
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | punta arenas
# Processing Record 11 of Set 3 | plouzane
# Processing Record 12 of Set 3 | ibra
# Processing Record 13 of Set 3 | bilma
# Processing Record 14 of Set 3 | apac
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | makakilo city
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | krasnogorskoye
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | upernavik
# Processing Record 22 of Set 3 | qianan
# Processing Record 23 of Set 3 | yar-sale
# Processing Record 24 of Set 3 | tondano
# Processing Record 25 of Set 3 | dwarka
# Processing Record 26 of Set 3 | century village
# Processing Record 27 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | khatanga
# Processing Record 30 of Set 3 | qaanaaq
# Processing Record 31 of Set 3 | oranjemund
# Processing Record 32 of Set 3 | kudahuvadhoo
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | provideniya
# Processing Record 36 of Set 3 | abnub
# Processing Record 37 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 3 | ambilobe
# Processing Record 39 of Set 3 | gushikawa
# Processing Record 40 of Set 3 | domoni
# Processing Record 41 of Set 3 | san patricio
# Processing Record 42 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 3 | inhambane
# Processing Record 44 of Set 3 | alyangula
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | lugovoy
# Processing Record 47 of Set 3 | bereda
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | zhangjiakou
# Processing Record 2 of Set 4 | leirvik
# Processing Record 3 of Set 4 | puerto carreno
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | morgan city
# Processing Record 6 of Set 4 | abu dhabi
# Processing Record 7 of Set 4 | san onofre
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | vezirkopru
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | lichinga
# Processing Record 14 of Set 4 | novokayakent
# Processing Record 15 of Set 4 | milton
# Processing Record 16 of Set 4 | qovlar
# Processing Record 17 of Set 4 | tessalit
# Processing Record 18 of Set 4 | gambela
# Processing Record 19 of Set 4 | kabinda
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | gravdal
# Processing Record 22 of Set 4 | boshnyakovo
# Processing Record 23 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 4 | kurilsk
# Processing Record 25 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | campo verde
# Processing Record 28 of Set 4 | wa
# City not found. Skipping...
# Processing Record 29 of Set 4 | forio
# Processing Record 30 of Set 4 | sakaiminato
# Processing Record 31 of Set 4 | bay roberts
# Processing Record 32 of Set 4 | bluff
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | nome
# Processing Record 36 of Set 4 | dalvik
# Processing Record 37 of Set 4 | fairbanks
# Processing Record 38 of Set 4 | comodoro rivadavia
# Processing Record 39 of Set 4 | honiara
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | kavieng
# Processing Record 43 of Set 4 | ridgecrest
# Processing Record 44 of Set 4 | coffs harbour
# Processing Record 45 of Set 4 | rio verde de mato grosso
# Processing Record 46 of Set 4 | tura
# Processing Record 47 of Set 4 | yuci
# Processing Record 48 of Set 4 | opunake
# Processing Record 49 of Set 4 | aksha
# Processing Record 50 of Set 4 | fortuna
# Processing Record 1 of Set 5 | khromtau
# Processing Record 2 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 5 | baglan
# Processing Record 4 of Set 5 | kieta
# Processing Record 5 of Set 5 | point fortin
# Processing Record 6 of Set 5 | grand gaube
# Processing Record 7 of Set 5 | beloha
# Processing Record 8 of Set 5 | bairiki
# Processing Record 9 of Set 5 | port blair
# Processing Record 10 of Set 5 | cermik
# Processing Record 11 of Set 5 | victor harbor
# Processing Record 12 of Set 5 | caravelas
# Processing Record 13 of Set 5 | pontian kecil
# Processing Record 14 of Set 5 | butaritari
# Processing Record 15 of Set 5 | pangnirtung
# Processing Record 16 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 5 | szamotuly
# Processing Record 18 of Set 5 | leningradskiy
# Processing Record 19 of Set 5 | sao felix do xingu
# Processing Record 20 of Set 5 | luanda
# Processing Record 21 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | weinan
# Processing Record 24 of Set 5 | salaberry-de-valleyfield
# Processing Record 25 of Set 5 | sarandi
# Processing Record 26 of Set 5 | half moon bay
# Processing Record 27 of Set 5 | launceston
# Processing Record 28 of Set 5 | niagara falls
# Processing Record 29 of Set 5 | seddon
# Processing Record 30 of Set 5 | klaksvik
# Processing Record 31 of Set 5 | tasiilaq
# Processing Record 32 of Set 5 | verkhoyansk
# Processing Record 33 of Set 5 | suicheng
# Processing Record 34 of Set 5 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 5 | daru
# Processing Record 36 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 5 | santa cruz
# Processing Record 38 of Set 5 | gat
# Processing Record 39 of Set 5 | sitrah
# Processing Record 40 of Set 5 | storforshei
# Processing Record 41 of Set 5 | sibiti
# Processing Record 42 of Set 5 | la peca
# Processing Record 43 of Set 5 | mayumba
# Processing Record 44 of Set 5 | kassala
# Processing Record 45 of Set 5 | iroquois falls
# Processing Record 46 of Set 5 | alizai
# Processing Record 47 of Set 5 | ha
# City not found. Skipping...
# Processing Record 48 of Set 5 | saint-francois
# Processing Record 49 of Set 5 | phibun mangsahan
# Processing Record 50 of Set 5 | yellowknife
# Processing Record 1 of Set 6 | nizhnyaya tavda
# Processing Record 2 of Set 6 | surman
# Processing Record 3 of Set 6 | lucapa
# Processing Record 4 of Set 6 | namatanai
# Processing Record 5 of Set 6 | dikson
# Processing Record 6 of Set 6 | geraldton
# Processing Record 7 of Set 6 | portland
# Processing Record 8 of Set 6 | iquitos
# Processing Record 9 of Set 6 | da nang
# Processing Record 10 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 6 | pestravka
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 6 | gweru
# Processing Record 15 of Set 6 | sitka
# Processing Record 16 of Set 6 | green river
# Processing Record 17 of Set 6 | alenquer
# Processing Record 18 of Set 6 | korla
# Processing Record 19 of Set 6 | chekhov
# Processing Record 20 of Set 6 | flin flon
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | cesme
# Processing Record 23 of Set 6 | halifax
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | chokurdakh
# Processing Record 26 of Set 6 | christchurch
# Processing Record 27 of Set 6 | cavalcante
# Processing Record 28 of Set 6 | san cristobal
# Processing Record 29 of Set 6 | malartic
# Processing Record 30 of Set 6 | khovu-aksy
# Processing Record 31 of Set 6 | laibin
# Processing Record 32 of Set 6 | san juan
# Processing Record 33 of Set 6 | lakes entrance
# Processing Record 34 of Set 6 | bandiagara
# Processing Record 35 of Set 6 | zhaotong
# Processing Record 36 of Set 6 | rocha
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | saint-pierre
# Processing Record 39 of Set 6 | chuy
# Processing Record 40 of Set 6 | matagami
# Processing Record 41 of Set 6 | varkaus
# Processing Record 42 of Set 6 | rock springs
# Processing Record 43 of Set 6 | severnyy
# Processing Record 44 of Set 6 | tsaratanana
# Processing Record 45 of Set 6 | santa fe
# Processing Record 46 of Set 6 | copiapo
# Processing Record 47 of Set 6 | huilong
# Processing Record 48 of Set 6 | santa rita
# Processing Record 49 of Set 6 | matara
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 1 of Set 7 | alofi
# Processing Record 2 of Set 7 | port lincoln
# Processing Record 3 of Set 7 | ancud
# Processing Record 4 of Set 7 | norman wells
# Processing Record 5 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 7 | cidreira
# Processing Record 7 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 7 | mandalgovi
# Processing Record 9 of Set 7 | quzhou
# Processing Record 10 of Set 7 | banda aceh
# Processing Record 11 of Set 7 | griffith
# Processing Record 12 of Set 7 | mildura
# Processing Record 13 of Set 7 | tay ninh
# Processing Record 14 of Set 7 | isangel
# Processing Record 15 of Set 7 | les escoumins
# Processing Record 16 of Set 7 | asau
# Processing Record 17 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 7 | churapcha
# Processing Record 19 of Set 7 | kutum
# Processing Record 20 of Set 7 | rogovatoye
# Processing Record 21 of Set 7 | kidal
# Processing Record 22 of Set 7 | moses lake
# Processing Record 23 of Set 7 | souillac
# Processing Record 24 of Set 7 | libenge
# Processing Record 25 of Set 7 | sucua
# Processing Record 26 of Set 7 | touros
# Processing Record 27 of Set 7 | waddan
# Processing Record 28 of Set 7 | mwene-ditu
# Processing Record 29 of Set 7 | udachnyy
# Processing Record 30 of Set 7 | isla mujeres
# Processing Record 31 of Set 7 | saint-paul
# Processing Record 32 of Set 7 | bambous virieux
# Processing Record 33 of Set 7 | dingle
# Processing Record 34 of Set 7 | shebunino
# Processing Record 35 of Set 7 | baracoa
# Processing Record 36 of Set 7 | wattegama
# Processing Record 37 of Set 7 | chipinge
# Processing Record 38 of Set 7 | suoyarvi
# Processing Record 39 of Set 7 | huarmey
# Processing Record 40 of Set 7 | manadhoo
# Processing Record 41 of Set 7 | bajil
# Processing Record 42 of Set 7 | cravo norte
# Processing Record 43 of Set 7 | lincoln
# Processing Record 44 of Set 7 | dongsheng
# Processing Record 45 of Set 7 | ahuimanu
# Processing Record 46 of Set 7 | jinji
# Processing Record 47 of Set 7 | ixtapa
# Processing Record 48 of Set 7 | eirunepe
# Processing Record 49 of Set 7 | ushtobe
# Processing Record 50 of Set 7 | cayenne
# Processing Record 1 of Set 8 | hokitika
# Processing Record 2 of Set 8 | salalah
# Processing Record 3 of Set 8 | la rioja
# Processing Record 4 of Set 8 | heihe
# Processing Record 5 of Set 8 | umm lajj
# Processing Record 6 of Set 8 | los llanos de aridane
# Processing Record 7 of Set 8 | midland
# Processing Record 8 of Set 8 | caxito
# Processing Record 9 of Set 8 | deputatskiy
# Processing Record 10 of Set 8 | paamiut
# Processing Record 11 of Set 8 | ust-nera
# Processing Record 12 of Set 8 | ellisras
# Processing Record 13 of Set 8 | karratha
# Processing Record 14 of Set 8 | cairns
# Processing Record 15 of Set 8 | tautira
# Processing Record 16 of Set 8 | glendive
# Processing Record 17 of Set 8 | sala
# Processing Record 18 of Set 8 | houma
# Processing Record 19 of Set 8 | broome
# Processing Record 20 of Set 8 | pemangkat
# Processing Record 21 of Set 8 | akyab
# Processing Record 22 of Set 8 | berezovyy
# Processing Record 23 of Set 8 | raga
# Processing Record 24 of Set 8 | alta floresta
# Processing Record 25 of Set 8 | vostok
# Processing Record 26 of Set 8 | kemijarvi
# Processing Record 27 of Set 8 | mao
# Processing Record 28 of Set 8 | candido mendes
# Processing Record 29 of Set 8 | zyryanovskiy
# City not found. Skipping...
# Processing Record 30 of Set 8 | coronado
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | hualmay
# Processing Record 33 of Set 8 | linxia
# Processing Record 34 of Set 8 | rawson
# Processing Record 35 of Set 8 | mpika
# Processing Record 36 of Set 8 | ende
# Processing Record 37 of Set 8 | umred
# Processing Record 38 of Set 8 | samarai
# Processing Record 39 of Set 8 | emerald
# Processing Record 40 of Set 8 | yining
# Processing Record 41 of Set 8 | whitehorse
# Processing Record 42 of Set 8 | hays
# Processing Record 43 of Set 8 | villazon
# Processing Record 44 of Set 8 | yuanping
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | ploemeur
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | longyearbyen
# Processing Record 49 of Set 8 | neuquen
# Processing Record 50 of Set 8 | logan
# Processing Record 1 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 2 of Set 9 | pahalgam
# Processing Record 3 of Set 9 | luderitz
# Processing Record 4 of Set 9 | calabozo
# Processing Record 5 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 9 | ullapool
# Processing Record 7 of Set 9 | kamaishi
# Processing Record 8 of Set 9 | yulara
# Processing Record 9 of Set 9 | elat
# Processing Record 10 of Set 9 | bahadurganj
# Processing Record 11 of Set 9 | pinotepa de don luis
# Processing Record 12 of Set 9 | sao filipe
# Processing Record 13 of Set 9 | erzin
# Processing Record 14 of Set 9 | kerema
# Processing Record 15 of Set 9 | prince albert
# Processing Record 16 of Set 9 | bogandinskiy
# Processing Record 17 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 9 | predivinsk
# Processing Record 19 of Set 9 | yenagoa
# Processing Record 20 of Set 9 | te anau
# Processing Record 21 of Set 9 | kismayo
# Processing Record 22 of Set 9 | atambua
# Processing Record 23 of Set 9 | lata
# Processing Record 24 of Set 9 | gharo
# Processing Record 25 of Set 9 | cap malheureux
# Processing Record 26 of Set 9 | amot
# Processing Record 27 of Set 9 | constitucion
# Processing Record 28 of Set 9 | bosaso
# Processing Record 29 of Set 9 | alamosa
# Processing Record 30 of Set 9 | alugan
# Processing Record 31 of Set 9 | lorengau
# Processing Record 32 of Set 9 | segamat
# Processing Record 33 of Set 9 | boli
# Processing Record 34 of Set 9 | dawlatabad
# Processing Record 35 of Set 9 | ledyard
# Processing Record 36 of Set 9 | ciamis
# Processing Record 37 of Set 9 | kaka
# Processing Record 38 of Set 9 | puri
# Processing Record 39 of Set 9 | mwinilunga
# Processing Record 40 of Set 9 | kloulklubed
# Processing Record 41 of Set 9 | brae
# Processing Record 42 of Set 9 | monopoli
# Processing Record 43 of Set 9 | harper
# Processing Record 44 of Set 9 | nova odesa
# Processing Record 45 of Set 9 | okhotsk
# Processing Record 46 of Set 9 | progreso
# Processing Record 47 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 9 | luganville
# Processing Record 49 of Set 9 | puerto colombia
# Processing Record 50 of Set 9 | hervey bay
# Processing Record 1 of Set 10 | devonport
# Processing Record 2 of Set 10 | xinmin
# Processing Record 3 of Set 10 | nova venecia
# Processing Record 4 of Set 10 | sarangani
# Processing Record 5 of Set 10 | alice springs
# Processing Record 6 of Set 10 | pimentel
# Processing Record 7 of Set 10 | bambanglipuro
# Processing Record 8 of Set 10 | srednekolymsk
# Processing Record 9 of Set 10 | izhma
# Processing Record 10 of Set 10 | lohardaga
# Processing Record 11 of Set 10 | ta khmau
# Processing Record 12 of Set 10 | dutlwe
# Processing Record 13 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 10 | conthey
# Processing Record 15 of Set 10 | eyl
# Processing Record 16 of Set 10 | araouane
# Processing Record 17 of Set 10 | nampa
# Processing Record 18 of Set 10 | sola
# Processing Record 19 of Set 10 | ostrovnoy
# Processing Record 20 of Set 10 | meulaboh
# Processing Record 21 of Set 10 | locri
# Processing Record 22 of Set 10 | humberto de campos
# Processing Record 23 of Set 10 | bac lieu
# Processing Record 24 of Set 10 | vestmanna
# Processing Record 25 of Set 10 | asyut
# Processing Record 26 of Set 10 | kayes
# Processing Record 27 of Set 10 | taitung
# Processing Record 28 of Set 10 | tagusao
# Processing Record 29 of Set 10 | turayf
# Processing Record 30 of Set 10 | junction city
# Processing Record 31 of Set 10 | batticaloa
# Processing Record 32 of Set 10 | along
# Processing Record 33 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 10 | tomatlan
# Processing Record 35 of Set 10 | san policarpo
# Processing Record 36 of Set 10 | kuusamo
# Processing Record 37 of Set 10 | altoona
# Processing Record 38 of Set 10 | vila franca do campo
# Processing Record 39 of Set 10 | kavaratti
# Processing Record 40 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 10 | naze
# Processing Record 42 of Set 10 | moba
# Processing Record 43 of Set 10 | siocon
# Processing Record 44 of Set 10 | faya
# Processing Record 45 of Set 10 | manaure
# Processing Record 46 of Set 10 | raymond
# Processing Record 47 of Set 10 | ulaanbaatar
# Processing Record 48 of Set 10 | denizli
# Processing Record 49 of Set 10 | cozumel
# Processing Record 50 of Set 10 | dakar
# Processing Record 1 of Set 11 | troitskoye
# Processing Record 2 of Set 11 | mikuni
# Processing Record 3 of Set 11 | doka
# Processing Record 4 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 5 of Set 11 | jizan
# Processing Record 6 of Set 11 | lingao
# Processing Record 7 of Set 11 | moulmeingyun
# City not found. Skipping...
# Processing Record 8 of Set 11 | severobaykalsk
# Processing Record 9 of Set 11 | sakakah
# Processing Record 10 of Set 11 | fomboni
# Processing Record 11 of Set 11 | margate
# Processing Record 12 of Set 11 | taupo
# Processing Record 13 of Set 11 | san juan del sur
# Processing Record 14 of Set 11 | satipo
# Processing Record 15 of Set 11 | kerchevskiy
# Processing Record 16 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 11 | valdivia
# Processing Record 19 of Set 11 | kulhudhuffushi
# Processing Record 20 of Set 11 | pisco
# Processing Record 21 of Set 11 | baykit
# Processing Record 22 of Set 11 | roebourne
# Processing Record 23 of Set 11 | ondangwa
# Processing Record 24 of Set 11 | kangaatsiaq
# Processing Record 25 of Set 11 | salinopolis
# Processing Record 26 of Set 11 | cabedelo
# Processing Record 27 of Set 11 | salisbury
# Processing Record 28 of Set 11 | starominskaya
# Processing Record 29 of Set 11 | marystown
# Processing Record 30 of Set 11 | iqaluit
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | kununurra
# Processing Record 33 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 11 | waipawa
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | bollnas
# Processing Record 37 of Set 11 | imeni poliny osipenko
# Processing Record 38 of Set 11 | sarakhs
# Processing Record 39 of Set 11 | buraydah
# Processing Record 40 of Set 11 | tigil
# Processing Record 41 of Set 11 | auki
# Processing Record 42 of Set 11 | avanigadda
# Processing Record 43 of Set 11 | belaya gora
# Processing Record 44 of Set 11 | inuvik
# Processing Record 45 of Set 11 | gornopravdinsk
# Processing Record 46 of Set 11 | sept-iles
# Processing Record 47 of Set 11 | jinchang
# Processing Record 48 of Set 11 | altay
# Processing Record 49 of Set 11 | vung tau
# Processing Record 50 of Set 11 | oyama
# Processing Record 1 of Set 12 | brenham
# Processing Record 2 of Set 12 | langres
# Processing Record 3 of Set 12 | singapore
# Processing Record 4 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 12 | kushiro
# Processing Record 6 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 12 | mungwi
# Processing Record 8 of Set 12 | tukrah
# Processing Record 9 of Set 12 | buckeye
# Processing Record 10 of Set 12 | ailigandi
# Processing Record 11 of Set 12 | verin
# Processing Record 12 of Set 12 | torbay
# Processing Record 13 of Set 12 | great falls
# Processing Record 14 of Set 12 | onda
# Processing Record 15 of Set 12 | japura
# Processing Record 16 of Set 12 | cristobal obregon
# Processing Record 17 of Set 12 | zhangzhou
# Processing Record 18 of Set 12 | vestmannaeyjar
# Processing Record 19 of Set 12 | aitape
# Processing Record 20 of Set 12 | broken hill
# Processing Record 21 of Set 12 | union
# Processing Record 22 of Set 12 | hun
# Processing Record 23 of Set 12 | oistins
# Processing Record 24 of Set 12 | morondava
# Processing Record 25 of Set 12 | kavalerovo
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | peace river
# Processing Record 28 of Set 12 | movila banului
# Processing Record 29 of Set 12 | raha
# Processing Record 30 of Set 12 | palu
# Processing Record 31 of Set 12 | gornyy
# Processing Record 32 of Set 12 | polyarnyy
# Processing Record 33 of Set 12 | kikwit
# Processing Record 34 of Set 12 | manta
# Processing Record 35 of Set 12 | riwaka
# Processing Record 36 of Set 12 | huron
# Processing Record 37 of Set 12 | brigantine
# Processing Record 38 of Set 12 | chegdomyn
# Processing Record 39 of Set 12 | maracaju
# Processing Record 40 of Set 12 | valparaiso
# Processing Record 41 of Set 12 | qaqortoq
# Processing Record 42 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 12 | palauig
# Processing Record 44 of Set 12 | glendora
# Processing Record 45 of Set 12 | ternate
# Processing Record 46 of Set 12 | ilulissat
# Processing Record 47 of Set 12 | la ronge
# Processing Record 48 of Set 12 | cuamba
# Processing Record 49 of Set 12 | hambantota
# Processing Record 50 of Set 12 | santarem
# Processing Record 1 of Set 13 | aljezur
# Processing Record 2 of Set 13 | hohhot
# Processing Record 3 of Set 13 | vardo
# Processing Record 4 of Set 13 | mutoko
# Processing Record 5 of Set 13 | khandyga
# Processing Record 6 of Set 13 | znamenskoye
# Processing Record 7 of Set 13 | kadhan
# Processing Record 8 of Set 13 | ulaangom
# Processing Record 9 of Set 13 | laguna de perlas
# Processing Record 10 of Set 13 | waingapu
# Processing Record 11 of Set 13 | bayburt
# Processing Record 12 of Set 13 | manggar
# Processing Record 13 of Set 13 | komsomolskiy
# Processing Record 14 of Set 13 | sampit
# Processing Record 15 of Set 13 | fort saint james
# Processing Record 16 of Set 13 | ust-tsilma
# Processing Record 17 of Set 13 | uchkent
# Processing Record 18 of Set 13 | bafang
# Processing Record 19 of Set 13 | colonial park
# Processing Record 20 of Set 13 | hobyo
# Processing Record 21 of Set 13 | san quintin
# Processing Record 22 of Set 13 | batagay
# Processing Record 23 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 13 | teya
# Processing Record 25 of Set 13 | sao joao nepomuceno
# Processing Record 26 of Set 13 | nicoya
# Processing Record 27 of Set 13 | yei
# Processing Record 28 of Set 13 | loutra
# Processing Record 29 of Set 13 | pitimbu
# Processing Record 30 of Set 13 | dalnerechensk
# Processing Record 31 of Set 13 | chingirlau
# Processing Record 32 of Set 13 | vila velha
# Processing Record 33 of Set 13 | anadyr
# Processing Record 34 of Set 13 | nantucket
# Processing Record 35 of Set 13 | mikkeli
# Processing Record 36 of Set 13 | maniitsoq
# Processing Record 37 of Set 13 | puerto leguizamo
# Processing Record 38 of Set 13 | dejen
# Processing Record 39 of Set 13 | carballo
# Processing Record 40 of Set 13 | amga
# Processing Record 41 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 42 of Set 13 | sorland
# Processing Record 43 of Set 13 | saint-augustin
# Processing Record 44 of Set 13 | radford
# Processing Record 45 of Set 13 | barra patuca
# Processing Record 46 of Set 13 | praia
# Processing Record 47 of Set 13 | gandajika
# Processing Record 48 of Set 13 | aswan
# Processing Record 49 of Set 13 | chany
# Processing Record 50 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 14 | henties bay
# Processing Record 2 of Set 14 | sur
# Processing Record 3 of Set 14 | rio gallegos
# Processing Record 4 of Set 14 | zhezkazgan
# Processing Record 5 of Set 14 | omsukchan
# Processing Record 6 of Set 14 | maldonado
# Processing Record 7 of Set 14 | andilamena
# Processing Record 8 of Set 14 | yerbogachen
# Processing Record 9 of Set 14 | farafangana
# Processing Record 10 of Set 14 | os
# City not found. Skipping...
# Processing Record 11 of Set 14 | radviliskis
# Processing Record 12 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 14 | corrente
# Processing Record 15 of Set 14 | floresta
# Processing Record 16 of Set 14 | ulladulla
# Processing Record 17 of Set 14 | veraval
# Processing Record 18 of Set 14 | contai
# Processing Record 19 of Set 14 | jiazi
# Processing Record 20 of Set 14 | ladario
# Processing Record 21 of Set 14 | chincha alta
# Processing Record 22 of Set 14 | hailar
# Processing Record 23 of Set 14 | diffa
# Processing Record 24 of Set 14 | humaita
# Processing Record 25 of Set 14 | weyburn
# Processing Record 26 of Set 14 | mayo
# Processing Record 27 of Set 14 | reinosa
# Processing Record 28 of Set 14 | klyuchi
# Processing Record 29 of Set 14 | thaton
# Processing Record 30 of Set 14 | zhigansk
# Processing Record 31 of Set 14 | ust-omchug
# Processing Record 32 of Set 14 | west wendover
# Processing Record 33 of Set 14 | lamar
# Processing Record 34 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 35 of Set 14 | lewiston
# Processing Record 36 of Set 14 | san roque
# Processing Record 37 of Set 14 | nemuro
# Processing Record 38 of Set 14 | flinders
# Processing Record 39 of Set 14 | bikaner
# Processing Record 40 of Set 14 | south sioux city
# Processing Record 41 of Set 14 | chase
# Processing Record 42 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 43 of Set 14 | shimsk
# Processing Record 44 of Set 14 | santiago del estero
# Processing Record 45 of Set 14 | tiznit
# Processing Record 46 of Set 14 | grants
# Processing Record 47 of Set 14 | taseyevo
# Processing Record 48 of Set 14 | egvekinot
# Processing Record 49 of Set 14 | nam som
# Processing Record 50 of Set 14 | sao miguel do araguaia
# Processing Record 1 of Set 15 | batagay-alyta
# Processing Record 2 of Set 15 | nouadhibou
# Processing Record 3 of Set 15 | bitam
# Processing Record 4 of Set 15 | alice town
# Processing Record 5 of Set 15 | verkh-usugli
# Processing Record 6 of Set 15 | khuchni
# Processing Record 7 of Set 15 | songjianghe
# Processing Record 8 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 15 | fethiye
# Processing Record 10 of Set 15 | aksu
# Processing Record 11 of Set 15 | aquin
# Processing Record 12 of Set 15 | jackson
# Processing Record 13 of Set 15 | padang
# Processing Record 14 of Set 15 | beipiao
# Processing Record 15 of Set 15 | nanakuli
# Processing Record 16 of Set 15 | lasa
# Processing Record 17 of Set 15 | soma
# Processing Record 18 of Set 15 | honningsvag
# Processing Record 19 of Set 15 | miyazu
# Processing Record 20 of Set 15 | kilindoni
# Processing Record 21 of Set 15 | taylorville
# Processing Record 22 of Set 15 | bud
# Processing Record 23 of Set 15 | lashio
# Processing Record 24 of Set 15 | horki
# Processing Record 25 of Set 15 | grand island
# Processing Record 26 of Set 15 | alappuzha
# Processing Record 27 of Set 15 | idlib
# Processing Record 28 of Set 15 | kjopsvik
# Processing Record 29 of Set 15 | paka
# Processing Record 30 of Set 15 | frontera
# Processing Record 31 of Set 15 | bhadrapur
# Processing Record 32 of Set 15 | poltavka
# Processing Record 33 of Set 15 | nabire
# Processing Record 34 of Set 15 | rakiv lis
# Processing Record 35 of Set 15 | kamenka
# Processing Record 36 of Set 15 | tazovskiy
# Processing Record 37 of Set 15 | lieksa
# Processing Record 38 of Set 15 | nancha
# Processing Record 39 of Set 15 | hofn
# Processing Record 40 of Set 15 | cottonwood
# Processing Record 41 of Set 15 | rundu
# Processing Record 42 of Set 15 | narrabri
# Processing Record 43 of Set 15 | ilo
# Processing Record 44 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 15 | rio grande
# Processing Record 46 of Set 15 | butembo
# Processing Record 47 of Set 15 | port said
# Processing Record 48 of Set 15 | jacareacanga
# Processing Record 49 of Set 15 | strezhevoy
# Processing Record 50 of Set 15 | maralal
# Processing Record 1 of Set 16 | marquette
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Podgornoye  51.7350   39.1496     16.02        92         100
# 1      New Norfolk -42.7826  147.0587     71.10        44          76
# 2           Mpanda  -6.3655   31.0409     63.72        96         100
# 3        Nishihara  26.1842  127.7558     71.26        53          40
# 4       Nikolskoye  59.7035   30.7861     26.49        89         100
# 5  Arraial Do Cabo -22.9661  -42.0278     76.57        89         100
# 6             Lebu -37.6167  -73.6500     58.15        72           0
# 7         Novikovo  51.1537   37.8879      1.20       100          92
# 8        Alcantara  -2.4089  -44.4147     77.20        91         100
# 9            Kapaa  22.0752 -159.3190     76.98        82          20
#
#    Wind Speed Country   Current Description
# 0        4.47      RU       overcast clouds
# 1        9.37      AU            light rain
# 2        1.19      TZ       overcast clouds
# 3       16.11      JP      scattered clouds
# 4       13.76      RU       overcast clouds
# 5       23.80      BR       overcast clouds
# 6       19.17      CL             clear sky
# 7        4.29      RU       overcast clouds
# 8        5.68      BR  heavy intensity rain
# 9        4.61      US            few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Podgornoye      RU  51.7350   39.1496     16.02        92         100
# 1      New Norfolk      AU -42.7826  147.0587     71.10        44          76
# 2           Mpanda      TZ  -6.3655   31.0409     63.72        96         100
# 3        Nishihara      JP  26.1842  127.7558     71.26        53          40
# 4       Nikolskoye      RU  59.7035   30.7861     26.49        89         100
# 5  Arraial Do Cabo      BR -22.9661  -42.0278     76.57        89         100
# 6             Lebu      CL -37.6167  -73.6500     58.15        72           0
# 7         Novikovo      RU  51.1537   37.8879      1.20       100          92
# 8        Alcantara      BR  -2.4089  -44.4147     77.20        91         100
# 9            Kapaa      US  22.0752 -159.3190     76.98        82          20
#
#    Wind Speed   Current Description
# 0        4.47       overcast clouds
# 1        9.37            light rain
# 2        1.19       overcast clouds
# 3       16.11      scattered clouds
# 4       13.76       overcast clouds
# 5       23.80       overcast clouds
# 6       19.17             clear sky
# 7        4.29       overcast clouds
# 8        5.68  heavy intensity rain
# 9        4.61            few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv" 

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
